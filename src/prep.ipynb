# %%
## load packages
import os 
import pathlib
import gdown
import sklearn
import pyarrow
import pandas as pd
import numpy as np
import itertools
import re
from sklearn.preprocessing import OneHotEncoder
from sklearn.feature_extraction.text import CountVectorizer
from feature_processing import encode_multi_features, encode_categorical

pd.set_option('display.max_columns', None)

# %%
bills = pd.read_parquet("data/bills.parquet")
bills_test = bills.sample(n = 2000, random_state=400).dropna(thresh = 27)

# %%
##sumarry of passing bills and status
len(bills["status"])                                        # length all = 588786
len(bills["status"]) -  len(bills[bills["status"].notna()]) # length status: na = 52079

bills["status"].value_counts(dropna = False)
# Out:
# status
# 1.0    289724
# 4.0    134720
# 6.0     75121
# NaN     52079
# 2.0     25679
# 0.0      5016
# 5.0      3863
# 3.0      2584
# Name: count, dtype: int64

# %%
path = open("bills_status.txt", 'w')
path.write(bills_test[["status", "last_action", "state_unified_bill_id", "sine_die"]].head(1000).sort_values(by = "status").to_string())
path.close()

# %%
# Out:
# 29        6.0
# 30        4.0
# 31        4.0
# 32        4.0
# 33        4.0
#          ...
# 707285    NaN
# 707286    NaN
# 707287    NaN
# 707288    NaN
# 707289    NaN
# Name: status, Length: 588786, dtype: float64

# %%
positions = pd.read_parquet("data/positions.parquet")
blocks = pd.read_parquet("data/block_assignments.parquet")

# %%
blocks
# Out:
#                   entity_id  block_0  block_1  block_2  block_3  block_4  \
# 0                      MA_1     3283      150        0       12      3.0
# 1                     MA_10     4139       20       27       26      0.0
# 2                    MA_100     3291      209       42        6      0.0
# 3                   MA_1000     1311      128       62       26      0.0
# 4                   MA_1001       97      169       68        6      0.0
# ...                     ...      ...      ...      ...      ...      ...
# 82631  RI_S_0000002245_2022      261        5        2        0      0.0
# 82632  RI_H_0000007427_2018      261        5        2        0      0.0
# 82633  RI_S_0000002475_2018      261        5        2        0      0.0
# 82634  RI_H_0000005127_2019      261        5        2        0      0.0
# 82635  RI_H_0000006012_2021      261        5        2        0      0.0
#
#        block_5  block_6 state record_type
# 0          3.0      2.0    MA    lobbying
# 1          3.0      2.0    MA    lobbying
# 2          3.0      2.0    MA    lobbying
# 3          3.0      2.0    MA    lobbying
# 4          3.0      2.0    MA    lobbying
# ...        ...      ...   ...         ...
# 82631      NaN      NaN    RI    lobbying
# 82632      NaN      NaN    RI    lobbying
# 82633      NaN      NaN    RI    lobbying
# 82634      NaN      NaN    RI    lobbying
# 82635      NaN      NaN    RI    lobbying
#
# [82636 rows x 10 columns]

# %%
positions.loc[positions["state_unified_bill_id"].isin(bills_test["state_unified_bill_id"])]
# Out:
#         bill_version                                        client_name  \
# 758626          None               Nebraska State Education Association
# 759457          None                             Fremont Public Schools
# 760523          None               Nebraska State Education Association
# 760576          None               Nebraska State Education Association
# 760629          None               Nebraska State Education Association
# 760781          None               Nebraska State Education Association
# 760834          None               Nebraska State Education Association
# 760887          None               Nebraska State Education Association
# 760940          None               Nebraska State Education Association
# 760993          None               Nebraska State Education Association
# 761046          None               Nebraska State Education Association
# 764506          None                   American Wind Energy Association
# 764650          None                      American Communications, Inc.
# 764752          None                      American Communications, Inc.
# 766932          None                         Westside Community Schools
# 1694923      11151.0            Wisconsin Education Association Council
# 1695695      11151.0                                  AFSCME Council 11
# 1757455         None                    Montana Association of Counties
# 1758384         None  Montana Association of Oil, Gas & Coal Countie...
# 1760024         None                       MonTerra Energy Company, LLC
# 1760511         None            Western Environmental Trade Association
# 1762330         None                                Carpenter Creek LLC
# 1762668         None                           Washington Corportations
# 1766177         None                             Office of the Governor
# 1766209         None                             Office of the Governor
# 2027361         None                                      Senator Kraus
# 2027362         None                          Missouri Municipal League
#
#                            lobbyist_rep_name lobbyist_firm_name position  \
# 758626                      McGuire, Mark D.               None  SUPPORT
# 759457                      Nabb, Douglas L.               None  SUPPORT
# 760523                            Sears, Jay               None  SUPPORT
# 760576                         Guinan, Trish               None  SUPPORT
# 760629                Christiansen, Craig R.               None  SUPPORT
# 760781                        Clayburn, Neal               None  SUPPORT
# 760834                       Kilgarin, Karen               None  SUPPORT
# 760887                        Scherer, Larry               None  SUPPORT
# 760940                        Hoffman, Jerry               None  SUPPORT
# 760993                      Mikkelsen, Brian               None  SUPPORT
# 761046                           Wolf, Jesse               None  SUPPORT
# 764506   American Communications Group, Inc.               None  SUPPORT
# 764650                    Erickson, Julie S.               None  SUPPORT
# 764752                  Lombardi, Richard A.               None  SUPPORT
# 766932                   Schimek, Herbert H.               None  SUPPORT
# 1694923                                 None               None      FOR
# 1695695                                 None               None      FOR
# 1757455                                 None               None       MN
# 1758384                                 None               None       OP
# 1760024                                 None               None       SP
# 1760511                                 None               None       SP
# 1762330                                 None               None       SP
# 1762668                                 None               None       SP
# 1766177                                 None               None       SP
# 1766209                                 None               None       SP
# 2027361                                 None               None      FOR
# 2027362                                 None               None  AGAINST
#
#                        start_date end_date  year record_type  \
# 758626  2010-04-21 00:00:00+00:00      NaT  2010    lobbying
# 759457  2010-04-12 00:00:00+00:00      NaT  2010    lobbying
# 760523  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 760576  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 760629  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 760781  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 760834  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 760887  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 760940  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 760993  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 761046  2010-05-17 00:00:00+00:00      NaT  2010    lobbying
# 764506  2010-05-27 00:00:00+00:00      NaT  2010    lobbying
# 764650  2010-05-27 00:00:00+00:00      NaT  2010    lobbying
# 764752  2010-05-27 00:00:00+00:00      NaT  2010    lobbying
# 766932  2010-05-12 00:00:00+00:00      NaT  2010    lobbying
# 1694923 2014-02-06 00:00:00+00:00      NaT  2014    lobbying
# 1695695 2014-02-06 00:00:00+00:00      NaT  2014    lobbying
# 1757455 2009-05-14 10:23:53+00:00      NaT  2010    lobbying
# 1758384 2009-05-12 08:54:19+00:00      NaT  2010    lobbying
# 1760024 2009-05-29 12:26:21+00:00      NaT  2010    lobbying
# 1760511 2009-05-26 11:15:51+00:00      NaT  2010    lobbying
# 1762330 2009-05-19 15:02:33+00:00      NaT  2010    lobbying
# 1762668 2009-05-06 14:53:38+00:00      NaT  2010    lobbying
# 1766177 2009-04-10 14:20:31+00:00      NaT  2010    lobbying
# 1766209 2009-05-12 14:06:24+00:00      NaT  2010    lobbying
# 2027361                       NaT      NaT  2012   testimony
# 2027362                       NaT      NaT  2012   testimony
#
#                       session  \
# 758626                  2010R
# 759457                  2010R
# 760523                  2010R
# 760576                  2010R
# 760629                  2010R
# 760781                  2010R
# 760834                  2010R
# 760887                  2010R
# 760940                  2010R
# 760993                  2010R
# 761046                  2010R
# 764506                  2010R
# 764650                  2010R
# 764752                  2010R
# 766932                  2010R
# 1694923               2013REG
# 1695695               2013REG
# 1757455                  2009
# 1758384                  2009
# 1760024                  2009
# 1760511                  2009
# 1762330                  2009
# 1762668                  2009
# 1766177                  2009
# 1766209                  2009
# 2027361  2012 Regular Session
# 2027362  2012 Regular Session
#
#                                                description committee state  \
# 758626   Amendments: \nDescription: Authorize leases on...      None    NE
# 759457   Amendments: \nDescription: Authorize leases on...      None    NE
# 760523   Amendments: \nDescription: Authorize leases on...      None    NE
# 760576   Amendments: \nDescription: Authorize leases on...      None    NE
# 760629   Amendments: \nDescription: Authorize leases on...      None    NE
# 760781   Amendments: \nDescription: Authorize leases on...      None    NE
# 760834   Amendments: \nDescription: Authorize leases on...      None    NE
# 760887   Amendments: \nDescription: Authorize leases on...      None    NE
# 760940   Amendments: \nDescription: Authorize leases on...      None    NE
# 760993   Amendments: \nDescription: Authorize leases on...      None    NE
# 761046   Amendments: \nDescription: Authorize leases on...      None    NE
# 764506   Amendments: \nDescription: Authorize leases on...      None    NE
# 764650   Amendments: \nDescription: Authorize leases on...      None    NE
# 764752   Amendments: \nDescription: Authorize leases on...      None    NE
# 766932   Amendments: \nDescription: Authorize leases on...      None    NE
# 1694923                                               None      None    WI
# 1695695                                               None      None    WI
# 1757455                                             SB 510      None    MT
# 1758384                                             SB 510      None    MT
# 1760024                                             SB 510      None    MT
# 1760511                                             SB 510      None    MT
# 1762330                                             SB 510      None    MT
# 1762668                                             SB 510      None    MT
# 1766177                                             SB 510      None    MT
# 1766209                                             SB 510      None    MT
# 2027361                                               None      None    MO
# 2027362                                               None      None    MO
#
#          position_numeric docket_number docket_prefix legiscan_bill_id  \
# 758626                1.0          None          None         150449.0
# 759457                1.0          None          None         150449.0
# 760523                1.0          None          None         150449.0
# 760576                1.0          None          None         150449.0
# 760629                1.0          None          None         150449.0
# 760781                1.0          None          None         150449.0
# 760834                1.0          None          None         150449.0
# 760887                1.0          None          None         150449.0
# 760940                1.0          None          None         150449.0
# 760993                1.0          None          None         150449.0
# 761046                1.0          None          None         150449.0
# 764506                1.0          None          None         150449.0
# 764650                1.0          None          None         150449.0
# 764752                1.0          None          None         150449.0
# 766932                1.0          None          None         150449.0
# 1694923               1.0          None          None         614330.0
# 1695695               1.0          None          None         614330.0
# 1757455               0.0        2166.0             D         180856.0
# 1758384              -1.0        2166.0             D         180856.0
# 1760024               1.0        2166.0             D         180856.0
# 1760511               1.0        2166.0             D         180856.0
# 1762330               1.0        2166.0             D         180856.0
# 1762668               1.0        2166.0             D         180856.0
# 1766177               1.0        2166.0             D         180856.0
# 1766209               1.0        2166.0             D         180856.0
# 2027361               1.0          None          None         346379.0
# 2027362              -1.0          None          None         346379.0
#
#          state_unified_bill_id state_client_id  \
# 758626    NE_L_0000000916_2009           NE_27
# 759457    NE_L_0000000916_2009          NE_326
# 760523    NE_L_0000000916_2009           NE_27
# 760576    NE_L_0000000916_2009           NE_27
# 760629    NE_L_0000000916_2009           NE_27
# 760781    NE_L_0000000916_2009           NE_27
# 760834    NE_L_0000000916_2009           NE_27
# 760887    NE_L_0000000916_2009           NE_27
# 760940    NE_L_0000000916_2009           NE_27
# 760993    NE_L_0000000916_2009           NE_27
# 761046    NE_L_0000000916_2009           NE_27
# 764506    NE_L_0000000916_2009          NE_924
# 764650    NE_L_0000000916_2009          NE_139
# 764752    NE_L_0000000916_2009          NE_139
# 766932    NE_L_0000000916_2009          NE_494
# 1694923  WI_SB_0000000558_2013          WI_542
# 1695695  WI_SB_0000000558_2013           WI_80
# 1757455   MT_S_0000000510_2009           MT_70
# 1758384   MT_S_0000000510_2009           MT_86
# 1760024   MT_S_0000000510_2009          MT_129
# 1760511   MT_S_0000000510_2009          MT_136
# 1762330   MT_S_0000000510_2009          MT_326
# 1762668   MT_S_0000000510_2009          MT_191
# 1766177   MT_S_0000000510_2009          MT_321
# 1766209   MT_S_0000000510_2009          MT_321
# 2027361  MO_SB_0000000569_2012         MO_7047
# 2027362  MO_SB_0000000569_2012          MO_135
#
#                                  ncsl_metatopics  \
# 758626                    ncsl_metatopic__energy
# 759457                    ncsl_metatopic__energy
# 760523                    ncsl_metatopic__energy
# 760576                    ncsl_metatopic__energy
# 760629                    ncsl_metatopic__energy
# 760781                    ncsl_metatopic__energy
# 760834                    ncsl_metatopic__energy
# 760887                    ncsl_metatopic__energy
# 760940                    ncsl_metatopic__energy
# 760993                    ncsl_metatopic__energy
# 761046                    ncsl_metatopic__energy
# 764506                    ncsl_metatopic__energy
# 764650                    ncsl_metatopic__energy
# 764752                    ncsl_metatopic__energy
# 766932                    ncsl_metatopic__energy
# 1694923            ncsl_metatopic__fiscal_policy
# 1695695            ncsl_metatopic__fiscal_policy
# 1757455                   ncsl_metatopic__energy
# 1758384                   ncsl_metatopic__energy
# 1760024                   ncsl_metatopic__energy
# 1760511                   ncsl_metatopic__energy
# 1762330                   ncsl_metatopic__energy
# 1762668                   ncsl_metatopic__energy
# 1766177                   ncsl_metatopic__energy
# 1766209                   ncsl_metatopic__energy
# 2027361  ncsl_metatopic__elections_and_campaigns
# 2027362  ncsl_metatopic__elections_and_campaigns
#
#                                                ncsl_topics
# 758626   ncsl_database__energy_legislation_tracking_dat...
# 759457   ncsl_database__energy_legislation_tracking_dat...
# 760523   ncsl_database__energy_legislation_tracking_dat...
# 760576   ncsl_database__energy_legislation_tracking_dat...
# 760629   ncsl_database__energy_legislation_tracking_dat...
# 760781   ncsl_database__energy_legislation_tracking_dat...
# 760834   ncsl_database__energy_legislation_tracking_dat...
# 760887   ncsl_database__energy_legislation_tracking_dat...
# 760940   ncsl_database__energy_legislation_tracking_dat...
# 760993   ncsl_database__energy_legislation_tracking_dat...
# 761046   ncsl_database__energy_legislation_tracking_dat...
# 764506   ncsl_database__energy_legislation_tracking_dat...
# 764650   ncsl_database__energy_legislation_tracking_dat...
# 764752   ncsl_database__energy_legislation_tracking_dat...
# 766932   ncsl_database__energy_legislation_tracking_dat...
# 1694923  ncsl_database__pension_legislation_database__n...
# 1695695  ncsl_database__pension_legislation_database__n...
# 1757455  ncsl_database__energy_legislation_tracking_dat...
# 1758384  ncsl_database__energy_legislation_tracking_dat...
# 1760024  ncsl_database__energy_legislation_tracking_dat...
# 1760511  ncsl_database__energy_legislation_tracking_dat...
# 1762330  ncsl_database__energy_legislation_tracking_dat...
# 1762668  ncsl_database__energy_legislation_tracking_dat...
# 1766177  ncsl_database__energy_legislation_tracking_dat...
# 1766209  ncsl_database__energy_legislation_tracking_dat...
# 2027361  ncsl_database__elections_legislation_database_...
# 2027362  ncsl_database__elections_legislation_database_...

# %%
#encoding features with different number of values
encode_multi_features(bills_test, "ncsl_metatopics", "; ")
encode_categorical(bills_test, ["state", "bill_chamber"])
# Out:
# (<Compressed Sparse Row sparse matrix of dtype 'float64'
#  	with 28 stored elements and shape (14, 16)>,
#  array(['state_AZ', 'state_FL', 'state_IL', 'state_MD', 'state_MO',
#         'state_MT', 'state_NE', 'state_NJ', 'state_RI', 'state_WI',
#         'bill_chamber_A', 'bill_chamber_H', 'bill_chamber_HB',
#         'bill_chamber_LB', 'bill_chamber_S', 'bill_chamber_SB'],
#        dtype=object))

# %%
#extract representative subset to test feature preperation
#make metatopic coolumn a list instead of a single string 
#bills_test["ncsl_metatopics"] = bills_test["ncsl_metatopics"].str.split("; ")
#bills_test_sub = bills_test[["state", "ncsl_metatopics"]].to_numpy() #extract columns and turn df to array
#bills_test_sub

# %%
print(bills_test_sub)
print(bills_test_sub.shape)

enc = OneHotEncoder(sparse_output=True)                             #define one hot encode
enc.fit(bills_test_sub)                                              #fit enc to subset
bills_test_sub_tr = enc.transform(bills_test_sub)                    #transform subset
enc.get_feature_names_out()
# Out:
# [['NE' list(['ncsl_metatopic__energy'])]
#  ['MO' list(['ncsl_metatopic__elections_and_campaigns'])]
#  ['MT' list(['ncsl_metatopic__energy'])]
#  ['IL' list(['ncsl_metatopic__energy'])]
#  ['FL' list(['ncsl_metatopic__technology_and_communication'])]
#  ['MO' list(['ncsl_metatopic__elections_and_campaigns'])]
#  ['IL' list(['ncsl_metatopic__ethics'])]
#  ['MO' list(['ncsl_metatopic__transportation'])]
#  ['MD' list(['ncsl_metatopic__transportation'])]
#  ['IL' list(['ncsl_metatopic__technology_and_communication'])]
#  ['WI'
#   list(['ncsl_metatopic__fiscal', 'ncsl_metatopic__labor_and_employment'])]
#  ['NJ' list(['ncsl_metatopic__transportation'])]
#  ['RI' list(['ncsl_metatopic__labor_and_employment'])]
#  ['AZ' list(['ncsl_metatopic__energy'])]]
# (14, 2)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /work/DPF_exam/env/lib/python3.12/site-packages/sklearn/utils/_encode.py:180, in _unique_python(values, return_inverse, return_counts)
#     179 try:
# --> 180     uniques_set = set(values)
#     181     uniques_set, missing_values = _extract_missing(uniques_set)
#
# TypeError: unhashable type: 'list'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[114], line 5
#       2 print(bills_test_sub.shape)
#       4 enc = OneHotEncoder(sparse_output=True)                             #define one hot encode
# ----> 5 enc.fit(bills_test_sub)                                              #fit enc to subset
#       6 bills_test_sub_tr = enc.transform(bills_test_sub)                    #transform subset
#       7 enc.get_feature_names_out()
#
# File /work/DPF_exam/env/lib/python3.12/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File /work/DPF_exam/env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:991, in OneHotEncoder.fit(self, X, y)
#     972 @_fit_context(prefer_skip_nested_validation=True)
#     973 def fit(self, X, y=None):
#     974     """
#     975     Fit OneHotEncoder to X.
#     976
#    (...)    989         Fitted encoder.
#     990     """
# --> 991     self._fit(
#     992         X,
#     993         handle_unknown=self.handle_unknown,
#     994         ensure_all_finite="allow-nan",
#     995     )
#     996     self._set_drop_idx()
#     997     self._n_features_outs = self._compute_n_features_outs()
#
# File /work/DPF_exam/env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:103, in _BaseEncoder._fit(self, X, handle_unknown, ensure_all_finite, return_counts, return_and_ignore_missing_for_infrequent)
#     100 Xi = X_list[i]
#     102 if self.categories == "auto":
# --> 103     result = _unique(Xi, return_counts=compute_counts)
#     104     if compute_counts:
#     105         cats, counts = result
#
# File /work/DPF_exam/env/lib/python3.12/site-packages/sklearn/utils/_encode.py:52, in _unique(values, return_inverse, return_counts)
#      21 """Helper function to find unique values with support for python objects.
#      22
#      23 Uses pure python method for object dtype, and numpy method for
#    (...)     49     array. Only provided if `return_counts` is True.
#      50 """
#      51 if values.dtype == object:
# ---> 52     return _unique_python(
#      53         values, return_inverse=return_inverse, return_counts=return_counts
#      54     )
#      55 # numerical
#      56 return _unique_np(
#      57     values, return_inverse=return_inverse, return_counts=return_counts
#      58 )
#
# File /work/DPF_exam/env/lib/python3.12/site-packages/sklearn/utils/_encode.py:188, in _unique_python(values, return_inverse, return_counts)
#     186 except TypeError:
#     187     types = sorted(t.__qualname__ for t in set(type(v) for v in values))
# --> 188     raise TypeError(
#     189         "Encoders require their input argument must be uniformly "
#     190         f"strings or numbers. Got {types}"
#     191     )
#     192 ret = (uniques,)
#     194 if return_inverse:
#
# TypeError: Encoders require their input argument must be uniformly strings or numbers. Got ['list']

# %%
enc.categories_
# Out:
# [array(['AZ', 'FL', 'IL', 'MD', 'MO', 'MT', 'NE', 'NJ', 'RI', 'WI'],
#        dtype=object),
#  array(['ncsl_metatopic__elections_and_campaigns',
#         'ncsl_metatopic__energy', 'ncsl_metatopic__ethics',
#         'ncsl_metatopic__fiscal; ncsl_metatopic__labor_and_employment',
#         'ncsl_metatopic__labor_and_employment',
#         'ncsl_metatopic__technology_and_communication',
#         'ncsl_metatopic__transportation'], dtype=object)]

# %%
#one hot encoding of states
states = bills["state"].unique()
enc = OneHotEncoder(categories=[states])

b_states = bills["state"][29:100].array.reshape(-1, 1)
b_states_new = enc.fit_transform(b_states)
